# %% [markdown]
# # Chương 12. Trực quan hóa như một công cụ phân tích
#
# **Mục tiêu thực thi:** chạy từ kernel sạch, dùng dữ liệu đã đóng băng, và diễn giải đầu ra.

# %%
import warnings
warnings.filterwarnings("error", category=FutureWarning)
warnings.filterwarnings("error", category=DeprecationWarning)
from pathlib import Path
assert (Path.cwd()/"data").exists(), "Hãy chạy notebook từ thư mục gốc của gói Pass 9B."
print("Preflight: OK")

# %%
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt, pandas as pd
from pathlib import Path
df=pd.read_csv(Path.cwd()/"data/citypulse/citypulse_random_sample.csv")
fig,ax=plt.subplots(); ax.scatter(df["commute_minutes"],df["satisfaction_score"],s=8,alpha=.35); ax.set_xlabel("Thời gian đi lại (phút)"); ax.set_ylabel("Mức hài lòng"); ax.set_title("Thời gian đi lại và mức hài lòng"); out=Path.cwd()/"figures/output/ch12_notebook_scatter.svg"; fig.savefig(out); plt.close(fig)
assert out.exists()
print(out)

# %% [markdown]
# ## Diễn giải kết quả
#
# Đầu ra trên phải được đọc trong đúng đơn vị phân tích và phạm vi dữ liệu. **Kết quả chạy đúng không tự động chứng minh một nhận định mạnh hơn dữ liệu cho phép.**
