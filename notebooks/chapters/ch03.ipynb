# %% [markdown]
# # Chương 3. Cấu trúc dữ liệu, điều kiện và phép lặp
#
# **Mục tiêu thực thi:** chạy từ kernel sạch, dùng dữ liệu đã đóng băng, và diễn giải đầu ra.

# %%
import warnings
warnings.filterwarnings("error", category=FutureWarning)
warnings.filterwarnings("error", category=DeprecationWarning)
from pathlib import Path
assert (Path.cwd()/"data").exists(), "Hãy chạy notebook từ thư mục gốc của gói Pass 9B."
print("Preflight: OK")

# %%
customers=[{"customer_id":"C001","total_spend":1250,"visits":8},{"customer_id":"C002","total_spend":850,"visits":10},{"customer_id":"C003","total_spend":1450,"visits":3}]
results=[]
for c in customers:
    eligible=(c["total_spend"]>=1000) and (c["visits"]>=5)
    reason="eligible" if eligible else ("spend too low" if c["total_spend"]<1000 else "visits too low")
    results.append((c["customer_id"],eligible,reason))
assert sum(r[1] for r in results)==1
print(results)

# %% [markdown]
# ## Diễn giải kết quả
#
# Đầu ra trên phải được đọc trong đúng đơn vị phân tích và phạm vi dữ liệu. **Kết quả chạy đúng không tự động chứng minh một nhận định mạnh hơn dữ liệu cho phép.**
